# %% [markdown]
# <a href="https://colab.research.google.com/github/gowripreetham/SJSU_Pycaret/blob/main/Binary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/pycaret/pycaret.git@master --upgrade

# %%
import pycaret
pycaret.__version__

# %%
# ✅ Load Breast Cancer dataset directly from scikit-learn
from sklearn.datasets import load_breast_cancer
import pandas as pd

data = load_breast_cancer(as_frame=True)
df = data.frame

# Add target column (binary: 0 = malignant, 1 = benign)
df['target'] = data.target

print("✅ Dataset loaded successfully:", df.shape)
df.head()

# %%
from pycaret.classification import *

clf = setup(
    data=df,
    target='target',
    session_id=42,
    normalize=True,
    use_gpu=True,
    fold=5
)

# %%
best = compare_models()

# %%
evaluate_model(best)

# %%
tuned = tune_model(best)
final = finalize_model(tuned)
final

# %%
predictions = predict_model(final)
predictions.head()

# %%
save_model(final, 'binary_clf_best')
print("✅ Model saved as 'binary_clf_best.pkl'")
