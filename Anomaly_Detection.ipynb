# %% [markdown]
# <a href="https://colab.research.google.com/github/gowripreetham/SJSU_Pycaret/blob/main/Anomaly_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/pycaret/pycaret.git@master --upgrade

# %%
import pandas as pd
import seaborn as sns

# simple dataset for anomaly detection
df = sns.load_dataset("iris").drop(columns=["species"])
print("✅ Dataset loaded:", df.shape)
df.head()

# %%
from pycaret.anomaly import *

exp_ano = setup(
    data=df,
    session_id=42,
    normalize=True,
    use_gpu=True,    # 👈 enable GPU where supported
    html=False
)

# %%
iforest = create_model('iforest')
iforest

# %%
anomalies = assign_model(iforest)
anomalies.head()

# %%
plot_model(iforest, plot='tsne')

# %%
knn_model = create_model('knn')
assign_model(knn_model)
plot_model(knn_model, plot='tsne')

# %%
get_config('X_train_transformed').head()
print("Current seed:", get_config('seed'))
set_config('seed', 99)
print("New seed:", get_config('seed'))

# %%
new_data = df.sample(5, random_state=42)
preds = predict_model(iforest, data=new_data)
preds

# %%
save_model(iforest, 'anomaly_iforest_iris')
loaded_iforest = load_model('anomaly_iforest_iris')
print("✅ Model saved & reloaded successfully.")
